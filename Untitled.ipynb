# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns

engine = create_engine('postgresql://postgres:mysecretpassword@localhost:5432/postgres')

# Пример запроса: топ-10 самых продаваемых книг
query = """
    SELECT b.title, SUM(od.quantity * od.price) as revenue
    FROM books b
    JOIN order_details od ON b.book_id = od.book_id
    GROUP BY b.title
    ORDER BY revenue DESC
    LIMIT 10;
"""
df = pd.read_sql(query, engine)
print(df)

# Визуализация
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='revenue', y='title')
plt.title('Топ-10 книг по выручке')
plt.tight_layout()
plt.show()
# Out:
#                                                title   revenue
# 0                      Удобный и пошаговый модератор  39541.21
# 1     Оперативная и эвристическая производительность  35264.43
# 2        Ассимилированная и целостная нейронная сеть  33305.31
# 3              Делегируемая и исполнительная матрица  32653.10
# 4        Реализованное и асимметричное использование  31560.10
# 5                Уменьшенный и многозадачный продукт  30447.06
# 6                Эксклюзивное и третичное приложение  29280.09
# 7                    Цельное и переходное приложение  28573.02
# 8  Сокращенное и исполнительное программное обесп...  28382.42
# 9   Бизнес-ориентированная и систематическая матрица  27925.59
